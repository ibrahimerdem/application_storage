# %%
# %load_ext tensorboard
#!rm -rf ./logs/ 

import os
import pandas as pd
import numpy as np
import tensorflow as tf

from datetime import datetime
from tensorflow import keras
from tensorflow.keras import layers
from tensorboard.plugins.hparams import api as hp

import warnings
warnings.filterwarnings("ignore")

import sys
sys.path.append("../")

from aux_func import *
from models import *

print(tf.version.VERSION)
print(keras.__version__)

gpus = tf.config.list_physical_devices("GPU")        
log_gpus = tf.config.list_logical_devices('GPU')
print(len(gpus), "Physical GPUs,", len(log_gpus), "Logical GPU")

from psutil import *

# !lscpu|grep "Model name"
# !nvidia-smi -L
# Out:
# 2.7.0
# 2.7.0
# 1 Physical GPUs, 1 Logical GPU
# Model name:                      Intel(R) Core(TM) i7-1065G7 CPU @ 1.30GHz
# GPU 0: NVIDIA GeForce MX330 (UUID: GPU-4d2220a0-a8ad-9e2b-c6d3-6c49af0eb31b)
# 2021-12-27 13:25:20.845394: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-27 13:25:20.924909: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-27 13:25:20.925143: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-27 13:25:20.926709: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-12-27 13:25:20.927913: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-27 13:25:20.928124: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-27 13:25:20.928301: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-27 13:25:21.599001: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-27 13:25:21.599204: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-27 13:25:21.599365: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-27 13:25:21.599521: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1375 MB memory:  -> device: 0, name: NVIDIA GeForce MX330, pci bus id: 0000:01:00.0, compute capability: 6.1

# %%
data = pd.read_csv(
    "../time-basis-app/time_train_data.csv",
     sep=";")

# %%
df = data.copy()

# %%
pro_max = df["item_code"].astype("int64").max()
rec_max = df["recency"].astype("int64").max()
pay_max = df["payment"].astype("int64").max()
cat_max = df["category_code"].astype("int64").max()
met_max = df["method_code"].astype("int64").max()
mon_max = df["month"].astype("int64").max()
day_max = df["dayofweek"].astype("int64").max()
n_padded = 12
batch_size = 128
val_split = 0.1

# %%
def model_training(model, train_x, train_y, val_split,
                   batch_size=batch_size):
  
    es = keras.callbacks.EarlyStopping(monitor="val_loss",
                                       mode="min",
                                       verbose=1,
                                       patience=3)
    
    hist = model.fit(train_x, train_y,
                     batch_size=batch_size,
                     epochs=200,
                     verbose=0,
                     validation_split=val_split,
                     callbacks=[es])
    return hist

# %%
MODEL_NUM = hp.HParam("model_num", hp.Discrete([5]))
RNN_STYLE = hp.HParam("rnn_style", hp.Discrete(["lstm"]))
EMB_UNITS = hp.HParam("emb_units", hp.Discrete([32, 64, 96, 128]))
RNN_UNITS = hp.HParam("rnn_units", hp.Discrete([100, 200, 300, 400, 500, 600]))
DROP_RATE = hp.HParam("drop_rate", hp.Discrete([0.6, 0.8]))
L_RATE = hp.HParam("l_rate", hp.Discrete([0.001]))
REPLICATION = hp.HParam("replication", hp.Discrete([1, 2]))
METRIC_ACCURACY = "sparse_categorical_accuracy"

ldir = "logs/time-tune/"
with tf.summary.create_file_writer(ldir).as_default():
    hp.hparams_config(
          hparams=[MODEL_NUM, RNN_STYLE, EMB_UNITS, RNN_UNITS,
                   DROP_RATE, L_RATE, REPLICATION],
          metrics=[hp.Metric(METRIC_ACCURACY, display_name="accuracy")])

# %%
train_data = create_sequences(df)
train_data = create_splits(train_data)
train_list = make_padding(train_data, n_padded)

# %%
def run(run_dir, hparams, model):
    with tf.summary.create_file_writer(run_dir).as_default():
        hp.hparams(hparams)
        if hparams["model"]==1:
            input_list=[train_list[0]],
        elif hparams["model"]==2:
            input_list=[train_list[0], train_list[1]]
        elif hparams["model"]==3:
            input_list=[train_list[0], train_list[1],
                        train_list[5]]
        elif hparams["model"]==4:
            input_list=[train_list[0], train_list[1],
                        train_list[5], train_list[6]]
        elif hparams["model"]==5:
            input_list=[train_list[0], train_list[1],
                        train_list[5], train_list[6],
                        train_list[2]]
        elif hparams["model"]==6:
            input_list=[train_list[0], train_list[1],
                        train_list[5], train_list[6],
                        train_list[4]]
        elif hparams["model"]==7:
            input_list=[train_list[0], train_list[1],
                        train_list[5], train_list[6],
                        train_list[3]]
        else:
            input_list=[train_list[0], train_list[1],
                        train_list[5], train_list[6],
                        train_list[2], train_list[3]]
        hist = model_training(model,
                              input_list,
                              train_list[-1],
                              val_split,
                              batch_size)
        m = hist.history["val_sparse_categorical_accuracy"][-1]
        print("m:",m)  
        tf.summary.scalar(METRIC_ACCURACY, m, step=2)

# %%
session_num = 0
for bi in [False]:
    for s in RNN_STYLE.domain.values:
        for n in MODEL_NUM.domain.values:
            for e in EMB_UNITS.domain.values:
                for g in RNN_UNITS.domain.values:
                    for d in DROP_RATE.domain.values:
                        for l in L_RATE.domain.values:
                            for r in REPLICATION.domain.values:
                                hparams = {
                                    "bidirect": bi,
                                    "style": s,
                                    "model": n,
                                    "emb_unit": e,
                                    "rnn_unit": g,
                                    "dropout": d,
                                    "learning": l,
                                    "n_padded": n_padded,
                                    "item_max": pro_max+1,
                                    "rec_max": rec_max+1,
                                    "pay_max": pay_max+1,
                                    "cat_max": cat_max+1,
                                    "met_max": met_max+1,
                                    "mon_max": mon_max+1,
                                    "day_max": day_max+1,
                                    RNN_STYLE: s,
                                    MODEL_NUM: n,
                                    EMB_UNITS: e,
                                    RNN_UNITS: g,
                                    DROP_RATE: d,
                                    L_RATE: l,
                                    REPLICATION: r,
                                }
                                model = model_base(hparams)
                                run_name = f"model{n}"+"-"+str(session_num)+"-"+str(r)
                                print("Experiment: %s" % run_name)
                                run(ldir + run_name, hparams, model)
                            session_num += 1
# Out:
# Experiment: model5-0-1
# 2021-12-26 19:36:32.518875: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce MX330" frequency: 1594 num_cores: 3 environment { key: "architecture" value: "6.1" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 524288 shared_memory_size_per_multiprocessor: 98304 memory_size: 1449787392 bandwidth: 56064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2021-12-26 19:36:37.427549: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce MX330" frequency: 1594 num_cores: 3 environment { key: "architecture" value: "6.1" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 524288 shared_memory_size_per_multiprocessor: 98304 memory_size: 1449787392 bandwidth: 56064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# Epoch 00014: early stopping
# m: 0.36960867047309875
# Experiment: model5-0-2
# 2021-12-26 19:37:29.680798: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce MX330" frequency: 1594 num_cores: 3 environment { key: "architecture" value: "6.1" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 524288 shared_memory_size_per_multiprocessor: 98304 memory_size: 1449787392 bandwidth: 56064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2021-12-26 19:37:34.885161: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce MX330" frequency: 1594 num_cores: 3 environment { key: "architecture" value: "6.1" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 524288 shared_memory_size_per_multiprocessor: 98304 memory_size: 1449787392 bandwidth: 56064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# Epoch 00014: early stopping
# m: 0.37589260935783386
# Experiment: model5-1-1
# 2021-12-26 19:38:30.718721: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce MX330" frequency: 1594 num_cores: 3 environment { key: "architecture" value: "6.1" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 524288 shared_memory_size_per_multiprocessor: 98304 memory_size: 1449787392 bandwidth: 56064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2021-12-26 19:38:36.044514: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce MX330" frequency: 1594 num_cores: 3 environment { key: "architecture" value: "6.1" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 524288 shared_memory_size_per_multiprocessor: 98304 memory_size: 1449787392 bandwidth: 56064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# Epoch 00022: early stopping
# m: 0.37160810828208923
# Experiment: model5-1-2
# 2021-12-26 19:40:00.172750: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce MX330" frequency: 1594 num_cores: 3 environment { key: "architecture" value: "6.1" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 524288 shared_memory_size_per_multiprocessor: 98304 memory_size: 1449787392 bandwidth: 56064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2021-12-26 19:40:05.383389: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce MX330" frequency: 1594 num_cores: 3 environment { key: "architecture" value: "6.1" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 524288 shared_memory_size_per_multiprocessor: 98304 memory_size: 1449787392 bandwidth: 56064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# Epoch 00024: early stopping
# m: 0.3756069839000702
# Experiment: model5-2-1
# 2021-12-26 19:41:39.798753: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce MX330" frequency: 1594 num_cores: 3 environment { key: "architecture" value: "6.1" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 524288 shared_memory_size_per_multiprocessor: 98304 memory_size: 1449787392 bandwidth: 56064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2021-12-26 19:41:46.092115: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce MX330" frequency: 1594 num_cores: 3 environment { key: "architecture" value: "6.1" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 524288 shared_memory_size_per_multiprocessor: 98304 memory_size: 1449787392 bandwidth: 56064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# Epoch 00012: early stopping
# m: 0.35932591557502747
# Experiment: model5-2-2
# 2021-12-26 19:42:45.273977: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce MX330" frequency: 1594 num_cores: 3 environment { key: "architecture" value: "6.1" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 524288 shared_memory_size_per_multiprocessor: 98304 memory_size: 1449787392 bandwidth: 56064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2021-12-26 19:42:51.516383: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce MX330" frequency: 1594 num_cores: 3 environment { key: "architecture" value: "6.1" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 524288 shared_memory_size_per_multiprocessor: 98304 memory_size: 1449787392 bandwidth: 56064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# Epoch 00012: early stopping
# m: 0.37217938899993896
# Experiment: model5-3-1
# 2021-12-26 19:43:51.316810: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce MX330" frequency: 1594 num_cores: 3 environment { key: "architecture" value: "6.1" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 524288 shared_memory_size_per_multiprocessor: 98304 memory_size: 1449787392 bandwidth: 56064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2021-12-26 19:43:57.608447: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce MX330" frequency: 1594 num_cores: 3 environment { key: "architecture" value: "6.1" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 524288 shared_memory_size_per_multiprocessor: 98304 memory_size: 1449787392 bandwidth: 56064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# Epoch 00015: early stopping
# m: 0.393887460231781
# Experiment: model5-3-2
# 2021-12-26 19:45:11.501492: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce MX330" frequency: 1594 num_cores: 3 environment { key: "architecture" value: "6.1" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 524288 shared_memory_size_per_multiprocessor: 98304 memory_size: 1449787392 bandwidth: 56064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2021-12-26 19:45:17.730831: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce MX330" frequency: 1594 num_cores: 3 environment { key: "architecture" value: "6.1" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 524288 shared_memory_size_per_multiprocessor: 98304 memory_size: 1449787392 bandwidth: 56064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# Epoch 00015: early stopping
# m: 0.38903170824050903
# Experiment: model5-4-1
# 2021-12-26 19:46:32.512962: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce MX330" frequency: 1594 num_cores: 3 environment { key: "architecture" value: "6.1" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 524288 shared_memory_size_per_multiprocessor: 98304 memory_size: 1449787392 bandwidth: 56064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2021-12-26 19:46:40.045739: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce MX330" frequency: 1594 num_cores: 3 environment { key: "architecture" value: "6.1" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 524288 shared_memory_size_per_multiprocessor: 98304 memory_size: 1449787392 bandwidth: 56064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# Epoch 00012: early stopping
# m: 0.31905171275138855
# Experiment: model5-4-2
# 2021-12-26 19:47:53.270914: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce MX330" frequency: 1594 num_cores: 3 environment { key: "architecture" value: "6.1" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 524288 shared_memory_size_per_multiprocessor: 98304 memory_size: 1449787392 bandwidth: 56064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2021-12-26 19:48:00.746025: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce MX330" frequency: 1594 num_cores: 3 environment { key: "architecture" value: "6.1" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 524288 shared_memory_size_per_multiprocessor: 98304 memory_size: 1449787392 bandwidth: 56064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# Epoch 00012: early stopping
# m: 0.33304768800735474
# Experiment: model5-5-1
# 2021-12-26 19:49:12.102061: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce MX330" frequency: 1594 num_cores: 3 environment { key: "architecture" value: "6.1" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 524288 shared_memory_size_per_multiprocessor: 98304 memory_size: 1449787392 bandwidth: 56064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2021-12-26 19:49:20.098097: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce MX330" frequency: 1594 num_cores: 3 environment { key: "architecture" value: "6.1" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 524288 shared_memory_size_per_multiprocessor: 98304 memory_size: 1449787392 bandwidth: 56064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# Epoch 00013: early stopping
# m: 0.38360467553138733
# Experiment: model5-5-2
# 2021-12-26 19:50:39.204839: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce MX330" frequency: 1594 num_cores: 3 environment { key: "architecture" value: "6.1" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 524288 shared_memory_size_per_multiprocessor: 98304 memory_size: 1449787392 bandwidth: 56064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2021-12-26 19:50:46.680269: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce MX330" frequency: 1594 num_cores: 3 environment { key: "architecture" value: "6.1" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 524288 shared_memory_size_per_multiprocessor: 98304 memory_size: 1449787392 bandwidth: 56064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# Epoch 00015: early stopping
# m: 0.3827477991580963
# Experiment: model5-6-1
# 2021-12-26 19:52:17.928574: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce MX330" frequency: 1594 num_cores: 3 environment { key: "architecture" value: "6.1" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 524288 shared_memory_size_per_multiprocessor: 98304 memory_size: 1449787392 bandwidth: 56064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2021-12-26 19:52:25.753177: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce MX330" frequency: 1594 num_cores: 3 environment { key: "architecture" value: "6.1" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 524288 shared_memory_size_per_multiprocessor: 98304 memory_size: 1449787392 bandwidth: 56064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# Epoch 00012: early stopping
# m: 0.3150528371334076
# Experiment: model5-6-2
# 2021-12-26 19:53:44.012441: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce MX330" frequency: 1594 num_cores: 3 environment { key: "architecture" value: "6.1" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 524288 shared_memory_size_per_multiprocessor: 98304 memory_size: 1449787392 bandwidth: 56064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2021-12-26 19:53:51.767354: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce MX330" frequency: 1594 num_cores: 3 environment { key: "architecture" value: "6.1" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 524288 shared_memory_size_per_multiprocessor: 98304 memory_size: 1449787392 bandwidth: 56064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# Epoch 00012: early stopping
# m: 0.3141959309577942
# Experiment: model5-7-1
# 2021-12-26 19:55:09.401802: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce MX330" frequency: 1594 num_cores: 3 environment { key: "architecture" value: "6.1" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 524288 shared_memory_size_per_multiprocessor: 98304 memory_size: 1449787392 bandwidth: 56064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2021-12-26 19:55:17.171238: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce MX330" frequency: 1594 num_cores: 3 environment { key: "architecture" value: "6.1" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 524288 shared_memory_size_per_multiprocessor: 98304 memory_size: 1449787392 bandwidth: 56064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# Epoch 00013: early stopping
# m: 0.3607540726661682
# Experiment: model5-7-2
# 2021-12-26 19:56:42.050804: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce MX330" frequency: 1594 num_cores: 3 environment { key: "architecture" value: "6.1" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 524288 shared_memory_size_per_multiprocessor: 98304 memory_size: 1449787392 bandwidth: 56064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2021-12-26 19